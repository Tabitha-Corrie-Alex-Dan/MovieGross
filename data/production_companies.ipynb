# %%
import pandas as pd
import os

# %%
imdb_csv = os.path.join("data", "imdb_movies.csv")
imdb_df = pd.read_csv(imdb_csv, low_memory=False)
imdb_df.head()
# Out:
#   imdb_title_id title original_title  year date_published  \
# 0     tt0465963  1:01           1:01  2006      1/27/2006
# 1     tt5834036  1:54           1:54  2016      3/15/2017
# 2     tt1002561  2:13           2:13  2009      4/25/2009
# 3     tt1261041  2:22           2:22  2008     12/21/2010
# 4     tt0472582  2:37           2:37  2006      8/17/2006
#
#                       genre  duration      country language  \
# 0                     Drama        92  Denmark, UK   Danish
# 1              Drama, Sport       106       Canada   French
# 2  Drama, Mystery, Thriller        96          USA  English
# 3    Crime, Drama, Thriller       104       Canada  English
# 4                     Drama        95    Australia  English
#
#              director  ...                                             actors  \
# 0   Annette K. Olesen  ...  Mohammed Al-Bakier, Joy K. Petersen, Anette St...
# 1         Yan England  ...  Antoine Olivier Pilon, Sophie Nélisse, Lou-Pas...
# ...

# %%
imdb_df = imdb_df[["title", "year", "date_published", "genre", "country", "budget", "usa_gross_income", "metascore", "reviews_from_users", "reviews_from_critics", "production_company"]]
imdb_df.head()
# Out:
#   title  year date_published                     genre      country  \
# 0  1:01  2006      1/27/2006                     Drama  Denmark, UK
# 1  1:54  2016      3/15/2017              Drama, Sport       Canada
# 2  2:13  2009      4/25/2009  Drama, Mystery, Thriller          USA
# 3  2:22  2008     12/21/2010    Crime, Drama, Thriller       Canada
# 4  2:37  2006      8/17/2006                     Drama    Australia
#
#         budget usa_gross_income  metascore  reviews_from_users  \
# 0          NaN              NaN        NaN                 3.0
# 1          NaN              NaN       46.0                19.0
# 2  $3,500,000               NaN        NaN                14.0
# 3          NaN              NaN        NaN                19.0
# 4  AUD 1000000              NaN        NaN                77.0
#
#    reviews_from_critics  production_company
# 0                  11.0         Sigma Films
# 1                  14.0  Cinémaginaire Inc.
# ...

# %%
usa_filter = ["USA"]
usa_imdb = imdb_df.loc[imdb_df["country"].isin(["USA"])]
usa_imdb
# Out:
#                         title  year date_published  \
# 2                        2:13  2009      4/25/2009
# 5                        3:15  1986      1/31/1986
# 12                       8:46  2011       9/4/2012
# 14                       0.45  2006     11/30/2006
# 15                      11:55  2016       6/9/2017
# ...                       ...   ...            ...
# 85770                   Zorro  1939     12/16/1939
# 85775                   Zotz!  1962       7/1/1962
# 85779  Zozza Mary, pazzo Gary  1974      5/17/1974
# 85852               Zyzzyx Rd  2006      2/24/2006
# 85854                  #NAME?  1932       4/9/1932
#
#                             genre country       budget usa_gross_income  \
# 2        Drama, Mystery, Thriller     USA  $3,500,000               NaN
# 5          Crime, Drama, Thriller     USA          NaN              NaN
# 12                          Drama     USA     $25,000               NaN
# ...

# %%
usa_imdb['production_company'].nunique()
# Out:
# 11479

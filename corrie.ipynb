# %%
import pandas as pd
import os

# %%
imdb_csv = os.path.join("data", "imdb_movies.csv")
imdb_df = pd.read_csv(imdb_csv, low_memory=False)
imdb_df.head()
# Out:
#   imdb_title_id title original_title  year date_published  \
# 0     tt0465963  1:01           1:01  2006      1/27/2006
# 1     tt5834036  1:54           1:54  2016      3/15/2017
# 2     tt1002561  2:13           2:13  2009      4/25/2009
# 3     tt1261041  2:22           2:22  2008     12/21/2010
# 4     tt0472582  2:37           2:37  2006      8/17/2006
#
#                       genre  duration      country language  \
# 0                     Drama        92  Denmark, UK   Danish
# 1              Drama, Sport       106       Canada   French
# 2  Drama, Mystery, Thriller        96          USA  English
# 3    Crime, Drama, Thriller       104       Canada  English
# 4                     Drama        95    Australia  English
#
#              director  ...                                             actors  \
# 0   Annette K. Olesen  ...  Mohammed Al-Bakier, Joy K. Petersen, Anette St...
# 1         Yan England  ...  Antoine Olivier Pilon, Sophie Nélisse, Lou-Pas...
# ...

# %%
imdb_df = imdb_df[["imdb_title_id", "title", "original_title", "year", "date_published", "genre", "country", "avg_vote", "votes", "budget", "usa_gross_income", "metascore", "reviews_from_users", "reviews_from_critics"]]
imdb_df.head()
# Out:
#   imdb_title_id title original_title  year date_published  \
# 0     tt0465963  1:01           1:01  2006      1/27/2006
# 1     tt5834036  1:54           1:54  2016      3/15/2017
# 2     tt1002561  2:13           2:13  2009      4/25/2009
# 3     tt1261041  2:22           2:22  2008     12/21/2010
# 4     tt0472582  2:37           2:37  2006      8/17/2006
#
#                       genre      country  avg_vote  votes       budget  \
# 0                     Drama  Denmark, UK       5.9    302          NaN
# 1              Drama, Sport       Canada       6.6   1335          NaN
# 2  Drama, Mystery, Thriller          USA       4.9   1120  $3,500,000
# 3    Crime, Drama, Thriller       Canada       5.2   1290          NaN
# 4                     Drama    Australia       6.8   6918  AUD 1000000
#
#   usa_gross_income  metascore  reviews_from_users  reviews_from_critics
# 0              NaN        NaN                 3.0                  11.0
# ...

# %%
imdb_df.count()
# Out:
# imdb_title_id           85855
# title                   85855
# original_title          85855
# year                    85855
# date_published          85855
# genre                   85855
# country                 85791
# avg_vote                85855
# votes                   85855
# budget                  23710
# usa_gross_income        15326
# metascore               13305
# reviews_from_users      78258
# reviews_from_critics    74058
# dtype: int64

# %%
usa_filter = ["USA"]
usa_imdb = imdb_df.loc[imdb_df["country"].isin(usa_filter)]
usa_imdb
# Out:
#       imdb_title_id                   title           original_title  year  \
# 2         tt1002561                    2:13                     2:13  2009
# 5         tt0090564                    3:15                     3:15  1986
# 12        tt2048688                    8:46                     8:46  2011
# 14        tt0259822                    0.45                     0.45  2006
# 15        tt4250438                   11:55                    11:55  2016
# ...             ...                     ...                      ...   ...
# 85770     tt0032164                   Zorro  Zorro's Fighting Legion  1939
# 85775     tt0056725                   Zotz!                    Zotz!  1962
# 85779     tt0071424  Zozza Mary, pazzo Gary   Dirty Mary Crazy Larry  1974
# 85852     tt0429277               Zyzzyx Rd                Zyzzyx Rd  2006
# 85854     tt0022731                  #NAME?                   #NAME?  1932
#
# ...

# %%
usa_imdb['budget'] = usa_imdb['budget'].str.replace(r"[a-zA-Z]",'')
# Out:
# <ipython-input-37-e2de82120298>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_imdb['budget'] = usa_imdb['budget'].str.replace(r"[a-zA-Z]",'')

# %%
usa_imdb.sort_values(by='budget', ascending=False, inplace=True)
# Out:
# <ipython-input-40-3d47c20de30f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_imdb.sort_values(by='budget', ascending=False, inplace=True)

# %%
usa_imdb
# Out:
#       imdb_title_id                    title           original_title  year  \
# 39675     tt0043117  La carovana dei mormoni             Wagon Master  1950
# 59902     tt0043120           Prego sorrida!         Watch the Birdie  1950
# 80236     tt0050771      Un urlo nella notte          No Down Payment  1957
# 82721     tt0029546    Voglio danzare con te           Shall We Dance  1937
# 4362      tt4733536            American Hero            American Hero  2015
# ...             ...                      ...                      ...   ...
# 85756     tt5340882                 Zoombies                 Zoombies  2016
# 85762     tt0083365                Zoot Suit                Zoot Suit  1981
# 85770     tt0032164                    Zorro  Zorro's Fighting Legion  1939
# 85775     tt0056725                    Zotz!                    Zotz!  1962
# 85854     tt0022731                   #NAME?                   #NAME?  1932
#
# ...

# %%
usa_imdb.value
# Out:
#       imdb_title_id                 title           original_title  year  \
# 78421     tt2197776  Training for a Fight     Training for a Fight  2012
# 75212     tt0088751     The Naked Monster        The Naked Monster  2005
# 35397     tt0110169   It's Pat: The Movie      It's Pat: The Movie  1994
# 37353     tt0044788               Kangarù                 Kangaroo  1952
# 55017     tt0039737      Notte senza fine                  Pursued  1947
# ...             ...                   ...                      ...   ...
# 85756     tt5340882              Zoombies                 Zoombies  2016
# 85762     tt0083365             Zoot Suit                Zoot Suit  1981
# 85770     tt0032164                 Zorro  Zorro's Fighting Legion  1939
# 85775     tt0056725                 Zotz!                    Zotz!  1962
# 85854     tt0022731                #NAME?                   #NAME?  1932
#
#       date_published                       genre country  avg_vote  votes  \
# ...

# %%
usa_imdb.sort_values(by='budget',ascending=False)
# Out:
#       imdb_title_id                title           original_title  year  \
# 75212     tt0088751    The Naked Monster        The Naked Monster  2005
# 35397     tt0110169  It's Pat: The Movie      It's Pat: The Movie  1994
# 40940     tt0082497              La mano                 The Hand  1981
# 83984     tt0209486   Wish You Were Dead       Wish You Were Dead  2001
# 28728     tt1524130       Hitler's Grave           Hitler's Grave  2010
# ...             ...                  ...                      ...   ...
# 85756     tt5340882             Zoombies                 Zoombies  2016
# 85762     tt0083365            Zoot Suit                Zoot Suit  1981
# 85770     tt0032164                Zorro  Zorro's Fighting Legion  1939
# 85775     tt0056725                Zotz!                    Zotz!  1962
# 85854     tt0022731               #NAME?                   #NAME?  1932
#
#       date_published                       genre country  avg_vote  votes  \
# ...

# %%
usa_imdb.head(50)
# Out:
#       imdb_title_id                           title  \
# 75212     tt0088751               The Naked Monster
# 35397     tt0110169             It's Pat: The Movie
# 40940     tt0082497                         La mano
# 83984     tt0209486              Wish You Were Dead
# 28728     tt1524130                  Hitler's Grave
# 75481     tt0156881                        The Pawn
# 37353     tt0044788                         Kangarù
# 55017     tt0039737                Notte senza fine
# 40179     tt0022268             La donna di platino
# 4033      tt9062580                           Alone
# 78421     tt2197776            Training for a Fight
# 45168     tt0055719                L'eroe di Sparta
# 76258     tt1525898               The Space Between
# 23351     tt0128216                       Flophouse
# 54636     tt0425308                           Noise
# 62110     tt1103256    Red sands - La forza occulta
# 83010     tt0338543                            Wake
# ...
